# %%
from eventlist_v4 import Eventlist
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [25, 10]

# %%
filePath = "/data02/gammaflash/DL0/acquisizione_2022_06_24/rpg0/wf_runId_00157_configId_00000_2022-06-24T14:43:57.694266.h5"

# %%
eventlist = Eventlist()
outputdir="/data02/gammaflash/"

# %%
eventlist.process_file(filePath, None, outputdir, True, 11, 13)
# Out:
# Processing /data02/gammaflash/DL0/acquisizione_2022_06_24/rpg0/wf_runId_00157_configId_00000_2022-06-24T14:43:57.694266.h5
# Waveform num. 11 ##############################
# la waveform num. 11 ha i seguenti peaks: [1228 1826] e mean value 133.52 and stdev 3.89224870736699
# integral 1312083.2799999998
# integralMM 1256516.1333333333
# integralEXP 1153657.2329618302
# integral 18031.239999999998
# integralMM 80.03810041287579
# integralEXP 322.66388577934254
# Waveform num. 12 ##############################
# la waveform num. 12 ha i seguenti peaks: [1197] e mean value 132.79 and stdev 4.1019385660928664
# integral 27727.120000000006
# integralMM 28349.69666666667
# integralEXP 24478.330472532558
# Waveform num. 13 ##############################
# la waveform num. 13 ha i seguenti peaks: [1195] e mean value 133.03 and stdev 3.615121021487386
# integral 8259.459999999997
# integralMM 8913.253333333332
# integralEXP 8866.702568145261
