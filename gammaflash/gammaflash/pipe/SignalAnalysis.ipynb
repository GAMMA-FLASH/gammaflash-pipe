# %%
import os
from eventlist_v4 import Eventlist
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [25, 10]

# %%
filePath = "/data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-23T22_59_57.061407.h5"

# %%
eventlist = Eventlist()
outputdir="/data02/gammaflash/"

# %%
eventlist.process_file(filePath, None, outputdir, True, 275, 277)
#eventlist.process_file(filePath, None, outputdir, False)
# Out:
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-23T22_59_57.061407.h5
# Waveform num. 275 ##############################
# la waveform num. 275 ha i seguenti peaks: [8391] e mean value 99.81 and stdev 3.6405906114255693
# integral 13043.610000000008
# integralMM 13571.973333333332
# integralEXP 9885.020162264182
# Waveform num. 276 ##############################
# la waveform num. 276 ha i seguenti peaks: [11065] e mean value 98.52 and stdev 4.557367661271142
# integral 29771.08
# integralMM 30934.386666666665
# integralEXP 26194.788455916012
# Waveform num. 277 ##############################
# la waveform num. 277 ha i seguenti peaks: [7278] e mean value 99.86 and stdev 3.6222092705971587
# integral 16179.699999999997
# integralMM 16209.613333333335
# integralEXP 15085.102232073907

# %%
#<Oscilloscope eqLevel="01" decimation="0001" trigSource="03" trigThresh="14746" trigHyst="000050" trigDelay="10240" trigDebounce="000010" />
#RPG101 200mV 14746
#RPG101 150 mV 15156 IN CORSO

#RPG102 100 mV 15565
#RPG102  50 mV 15975 IN CORSO

#RPG103 50 mV 15975 NOISE

# %%
! ls -d /archive/DL0/*/*
# Out:
# ls: cannot access '/archive/DL0/*/*': No such file or directory

# %%
#rpgname="RPG102"
#thr="100mV"
#directory="/archive/DL0/"+rpgname+"/"+thr
directory="/data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/"
outputdir=directory.replace("dl0", "dl2")

for file_name in os.listdir(directory):
    if file_name.endswith('.h5'):
        file_path = os.path.join(directory, file_name)
        eventlist.process_file(file_path, None, outputdir, False)
# Out:
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_13_59.924484.h5
# EXCEPTION: Peaks non trovati nella waveform 154 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_13_59.924484.h5
# EXCEPTION: Peaks non trovati nella waveform 4309 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_13_59.924484.h5
# EXCEPTION: Peaks non trovati nella waveform 8157 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_13_59.924484.h5
# EXCEPTION: Peaks non trovati nella waveform 8550 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_13_59.924484.h5
# EXCEPTION: Peaks non trovati nella waveform 8795 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_13_59.924484.h5
# EXCEPTION: Peaks non trovati nella waveform 9606 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_13_59.924484.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_46_26.576661.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_15_53.936497.h5
# EXCEPTION: Peaks non trovati nella waveform 2338 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_15_53.936497.h5
# EXCEPTION: Peaks non trovati nella waveform 7949 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_15_53.936497.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_36_54.340240.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_17_48.711410.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_48_20.876564.h5
# EXCEPTION: Peaks non trovati nella waveform 1576 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_48_20.876564.h5
# EXCEPTION: Peaks non trovati nella waveform 6456 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_48_20.876564.h5
# EXCEPTION: Peaks non trovati nella waveform 9866 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_48_20.876564.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_19_43.199921.h5
# EXCEPTION: Peaks non trovati nella waveform 1878 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_19_43.199921.h5
# EXCEPTION: Peaks non trovati nella waveform 5688 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_19_43.199921.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_52_12.887610.h5
# EXCEPTION: Peaks non trovati nella waveform 7674 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_52_12.887610.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_21_37.579572.h5
# EXCEPTION: Peaks non trovati nella waveform 2834 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_21_37.579572.h5
# EXCEPTION: Peaks non trovati nella waveform 3733 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_21_37.579572.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_38_48.423495.h5
# EXCEPTION: Peaks non trovati nella waveform 3162 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_38_48.423495.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_23_32.155583.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_40_42.333264.h5
# EXCEPTION: Peaks non trovati nella waveform 6874 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_40_42.333264.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_54_07.891797.h5
# EXCEPTION: Peaks non trovati nella waveform 4844 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_54_07.891797.h5
# EXCEPTION: Peaks non trovati nella waveform 4871 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_54_07.891797.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_25_27.353376.h5
# EXCEPTION: Peaks non trovati nella waveform 1944 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_25_27.353376.h5
# EXCEPTION: Peaks non trovati nella waveform 2398 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_25_27.353376.h5
# EXCEPTION: Peaks non trovati nella waveform 6691 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_25_27.353376.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_27_21.528702.h5
# EXCEPTION: Peaks non trovati nella waveform 4995 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_27_21.528702.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_42_37.586514.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_56_03.239235.h5
# EXCEPTION: Peaks non trovati nella waveform 714 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_56_03.239235.h5
# EXCEPTION: Peaks non trovati nella waveform 7588 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_56_03.239235.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_29_14.814574.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_44_31.662266.h5
# EXCEPTION: Peaks non trovati nella waveform 5596 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_44_31.662266.h5
# EXCEPTION: Peaks non trovati nella waveform 9498 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_44_31.662266.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_31_10.091201.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_57_58.542279.h5
# EXCEPTION: Peaks non trovati nella waveform 7718 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_57_58.542279.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_33_04.580315.h5
# EXCEPTION: Peaks non trovati nella waveform 1328 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_33_04.580315.h5
# EXCEPTION: Peaks non trovati nella waveform 8438 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_33_04.580315.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_34_59.255378.h5
# EXCEPTION: Peaks non trovati nella waveform 7612 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_34_59.255378.h5
# EXCEPTION: Peaks non trovati nella waveform 8569 del file /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_34_59.255378.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_59_51.835178.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-01T16_50_16.627789.h5
# Processing /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl0/wf_runId_00334_configId_00001_2023-08-06T14_34_06.537465.h5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       8 if file_name.endswith('.h5'):
#       9     file_path = os.path.join(directory, file_name)
# ---> 10     eventlist.process_file(file_path, None, outputdir, False)
#
# File ~/workspace/gammaflash-pipe/gammaflash/gammaflash/pipe/eventlist_v4.py:138, in Eventlist.process_file(self, filename, temperatures, outdir, log, startEvent, endEvent)
#     136 shape_data = -1
#     137 lenwf = -1
# --> 138 for i, data in enumerate(group):
#     139     if i < int(startEvent):
#     140         continue
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/group.py:713, in Group._f_iter_nodes(self, classname)
#     710 if not classname:
#     711     # Returns all the children alphanumerically sorted
#     712     for name in sorted(self._v_children):
# --> 713         yield self._v_children[name]
#     714 elif classname == 'Group':
#     715     # Returns all the groups alphanumerically sorted
#     716     for name in sorted(self._v_groups):
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/misc/proxydict.py:23, in ProxyDict.__getitem__(self, key)
#      20     raise KeyError(key)
#      22 # Values are not actually stored to avoid extra references.
# ---> 23 return self._get_value_from_container(self._get_container(), key)
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/group.py:28, in _ChildrenDict._get_value_from_container(self, container, key)
#      27 def _get_value_from_container(self, container, key):
# ---> 28     return container._f_get_child(key)
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/group.py:685, in Group._f_get_child(self, childname)
#     682 self._g_check_has_child(childname)
#     684 childpath = join_path(self._v_pathname, childname)
# --> 685 return self._v_file._get_node(childpath)
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/file.py:1556, in File._get_node(self, nodepath)
#    1553 if nodepath == '/':
#    1554     return self.root
# -> 1556 node = self._node_manager.get_node(nodepath)
#    1557 assert node is not None, "unable to instantiate node ``%s``" % nodepath
#    1559 return node
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/file.py:417, in NodeManager.get_node(self, key)
#     414         node = None
#     416 if self.node_factory:
# --> 417     node = self.node_factory(key)
#     418     self.cache_node(node, key)
#     420 return node
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/group.py:1158, in RootGroup._g_load_child(self, childname)
#    1154 # Building a leaf may still fail because of unsupported types
#    1155 # and other causes.
#    1156 # return ChildClass(self, childname)  # uncomment for debugging
#    1157 try:
# -> 1158     return ChildClass(self, childname)
#    1159 except Exception as exc:  # XXX
#    1160     warnings.warn(
#    1161         "problems loading leaf ``%s``::\n\n"
#    1162         "  %s\n\n"
#    1163         "The leaf will become an ``UnImplemented`` node."
#    1164         % (self._g_join(childname), exc))
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/carray.py:200, in CArray.__init__(self, parentnode, name, atom, shape, title, filters, chunkshape, byteorder, _log, track_times)
#     197         self._v_chunkshape = tuple(SizeType(s) for s in chunkshape)
#     199 # The `Array` class is not abstract enough! :(
# --> 200 super(Array, self).__init__(parentnode, name, new, filters,
#     201                             byteorder, _log, track_times)
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/leaf.py:260, in Leaf.__init__(self, parentnode, name, new, filters, byteorder, _log, track_times)
#     255 self._want_track_times = track_times
#     257 # Existing filters need not be read since `filters`
#     258 # is a lazy property that automatically handles their loading.
# --> 260 super().__init__(parentnode, name, _log)
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/node.py:258, in Node.__init__(self, parentnode, name, _log)
#     255         self._g_log_create()
#     257     # This allows extra operations after creating the node.
# --> 258     self._g_post_init_hook()
#     259 except Exception:
#     260     # If anything happens, the node must be closed
#     261     # to undo every possible registration made so far.
#     262     # We do *not* rely on ``__del__()`` doing it later,
#     263     # since it might never be called anyway.
#     264     self._f_close()
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/leaf.py:305, in Leaf._g_post_init_hook(self)
#     303 else:  # get flavor of existing node (if any)
#     304     if self._v_file.params['PYTABLES_SYS_ATTRS']:
# --> 305         flavor = getattr(self._v_attrs, 'FLAVOR', internal_flavor)
#     306         self._flavor = flavor_alias_map.get(flavor, flavor)
#     307     else:
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/utils.py:225, in lazyattr.<locals>.newfget(self)
#     223 if name in mydict:
#     224     return mydict[name]
# --> 225 mydict[name] = value = fget(self)
#     226 return value
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/node.py:159, in Node._v_attrs(self)
#     149 @lazyattr
#     150 def _v_attrs(self):
#     151     """The associated `AttributeSet` instance.
#     152
#     153     See Also
#    (...)
#     156
#     157     """
# --> 159     return self._AttributeSet(self)
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/attributeset.py:232, in AttributeSet.__init__(self, node)
#     228 dict_["_v_attrnamesuser"] = []
#     229 for attr in self._v_attrnames:
#     230     # put the attributes on the local dictionary to allow
#     231     # tab-completion
# --> 232     self.__getattr__(attr)
#     233     if issysattrname(attr):
#     234         self._v_attrnamessys.append(attr)
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/attributeset.py:291, in AttributeSet.__getattr__(self, name)
#     286 # Read the attribute from disk. This is an optimization to read
#     287 # quickly system attributes that are _string_ values, but it
#     288 # takes care of other types as well as for example NROWS for
#     289 # Tables and EXTDIM for EArrays
#     290 format_version = self._v__format_version
# --> 291 value = self._g_getattr(self._v_node, name)
#     293 # Check whether the value is pickled
#     294 # Pickled values always seems to end with a "."
#     295 maybe_pickled = (
#     296     isinstance(value, np.generic) and  # NumPy scalar?
#     297     value.dtype.type == np.bytes_ and  # string type?
#     298     value.itemsize > 0 and value.endswith(b'.'))
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/hdf5extension.pyx:782, in tables.hdf5extension.AttributeSet._g_getattr()
#
# File ~/.conda/envs/gammaflash/lib/python3.11/site-packages/tables/hdf5extension.pyx:265, in tables.hdf5extension.get_dtype_scalar()
#
# KeyboardInterrupt:

# %%
new_directory = directory.replace("DL0", "DL2")

# %%
new_directory

# %%
! rm /data02/gammaflash/DL0b/acquisizione_2023_08_01/rpg1/dl2/*.dl2.h5
